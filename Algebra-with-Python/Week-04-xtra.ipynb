# %% [markdown]
# <a href="https://colab.research.google.com/github/edatfreecodecamp/python-math/blob/main/Algebra-with-Python/Week-04-xtra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loop through function inputs

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
xmin = -10
xmax = 10
ymin = -10
ymax = 10

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

for x in range(10):
    y = 0.5*x + 1
    plt.plot([x],[y], 'ro')

plt.show()

# %% [markdown]
# Use an array as inputs

# %%
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 2*(xmax-xmin) 
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

print("x =", x, "y =", y)
y = 2*x +1
plt.plot(x,y, 'r')

plt.show()
# Out:
# x = [-10.          -9.48717949  -8.97435897  -8.46153846  -7.94871795
#   -7.43589744  -6.92307692  -6.41025641  -5.8974359   -5.38461538
#   -4.87179487  -4.35897436  -3.84615385  -3.33333333  -2.82051282
#   -2.30769231  -1.79487179  -1.28205128  -0.76923077  -0.25641026
#    0.25641026   0.76923077   1.28205128   1.79487179   2.30769231
#    2.82051282   3.33333333   3.84615385   4.35897436   4.87179487
#    5.38461538   5.8974359    6.41025641   6.92307692   7.43589744
#    7.94871795   8.46153846   8.97435897   9.48717949  10.        ] y = [-19.         -17.97435897 -16.94871795 -15.92307692 -14.8974359
#  -13.87179487 -12.84615385 -11.82051282 -10.79487179  -9.76923077
#   -8.74358974  -7.71794872  -6.69230769  -5.66666667  -4.64102564
#   -3.61538462  -2.58974359  -1.56410256  -0.53846154   0.48717949
#    1.51282051   2.53846154   3.56410256   4.58974359   5.61538462
#    6.64102564   7.66666667   8.69230769   9.71794872  10.74358974
# ...

# %% [markdown]
# More ways to customize a graph

# %%
import numpy as np

xmin = -10
xmax = 11
ymin = -10
ymax = 11
points = 3*(xmax-xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots(figsize=(10,5))
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

ax.set_xlabel("x values")
ax.set_ylabel("y values")
ax.set_title("Some Graph")
ax.grid(True)

ax.set_xticks(np.arange(xmin, xmax, 1))
ax.set_yticks(np.arange(ymin, ymax, 1))

y = 2*x +1
plt.plot(x,y, label='y=2x+1')
plt.plot([4],[6], 'ro', label='point')
plt.plot(x,3*x, 'orange', label='steeper line')
plt.legend()
plt.show()
